# %% [markdown]
# # [Markdown](https://www.markdownguide.org/) Practice
#
#  **Ngon**
#
# *hehe*

# %% [markdown]
# 1. Học Data science
# 2. Học Machine Learning
# 3. Học deep learning

# %% [markdown]
# * tăng Kiến thức
# * Tăng trải nghiệm
# * Tăng lương

# %% [markdown]
# ![Ngon](attachment:8192d7c6-6021-43f6-b554-91c6521f2b9e.png)

# %% [markdown]
# | **ngon** | **hehe**| **vip**|
# |---|---|---|
# |1 | 2|3|
# |ok|good|ác|
#   |
